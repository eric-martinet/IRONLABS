# %%
import pandas as pd

# %%
data = {
    "TransactionID": [1, 2, 3, 4, 5],
    "ClientID": [231, 765, 453, 231, 892],
    "Profession": ["Self-employed", "students", "Horeca", "self-employed", "finance"],
    "Bank_dep": ["009", "005", "007", "009", "003"],
    "Risk": ["High", "high", "medium", "high", "low"],
    "Number of credits": [2, 3, 5, 2, 3],
    "Revenue": [30200, 12700, 89400, 30200, 740000]
}

df = pd.DataFrame(data)
df.set_index("TransactionID", inplace = True)
df
# Out:
#                ClientID     Profession Bank_dep    Risk  Number of credits  \
# TransactionID
# 1                   231  Self-employed      009    High                  2
# 2                   765       students      005    high                  3
# 3                   453         Horeca      007  medium                  5
# 4                   231  self-employed      009    high                  2
# 5                   892        finance      003     low                  3
#
#                Revenue
# TransactionID
# 1                30200
# 2                12700
# 3                89400
# 4                30200
# 5               740000

# %%
# Categorical columns
categorical_cols = ["Profession", "Bank_dep", "Risk"]

# %%
# Dummy Encoder
df_dummies = df
pd.get_dummies(df_dummies)
# Out:
#                ClientID  Number of credits  Revenue  Profession_Horeca  \
# TransactionID
# 1                   231                  2    30200                  0
# 2                   765                  3    12700                  0
# 3                   453                  5    89400                  1
# 4                   231                  2    30200                  0
# 5                   892                  3   740000                  0
#
#                Profession_Self-employed  Profession_finance  \
# TransactionID
# 1                                     1                   0
# 2                                     0                   0
# 3                                     0                   0
# 4                                     0                   0
# 5                                     0                   1
#
#                Profession_self-employed  Profession_students  Bank_dep_003  \
# TransactionID
# 1                                     0                    0             0
# 2                                     0                    1             0
# 3                                     0                    0             0
# 4                                     1                    0             0
# 5                                     0                    0             1
#
#                Bank_dep_005  Bank_dep_007  Bank_dep_009  Risk_High  Risk_high  \
# TransactionID
# 1                         0             0             1          1          0
# 2                         1             0             0          0          1
# 3                         0             1             0          0          0
# 4                         0             0             1          0          1
# 5                         0             0             0          0          0
#
#                Risk_low  Risk_medium
# TransactionID
# 1                     0            0
# 2                     0            0
# 3                     0            1
# 4                     0            0
# 5                     1            0

# %%
# Label Encoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df_label_encoder = df

for col in categorical_cols:
    df_label_encoder[col + "_encode"]=encoder.fit_transform(df_label_encoder[col])
    
# df_label_encoder.drop(columns=categorical_cols, inplace = True)
df_label_encoder
# Out:
#                ClientID     Profession Bank_dep    Risk  Number of credits  \
# TransactionID
# 1                   231  Self-employed      009    High                  2
# 2                   765       students      005    high                  3
# 3                   453         Horeca      007  medium                  5
# 4                   231  self-employed      009    high                  2
# 5                   892        finance      003     low                  3
#
#                Revenue  Profession_encode  Bank_dep_encode  Risk_encode
# TransactionID
# 1                30200                  1                3            0
# 2                12700                  4                1            1
# 3                89400                  0                2            3
# 4                30200                  3                3            1
# 5               740000                  2                0            2

# %%
# Backward Difference Coding
from category_encoders.backward_difference import BackwardDifferenceEncoder
encoder = BackwardDifferenceEncoder()

df_backward_difference_encoder = df

for col in categorical_cols:
    df_backward_difference_encoder[col + "_encode"]=encoder.fit_transform(df_backward_difference_encoder[col])

# df_backward_difference_encoder.drop(columns=categorical_cols, inplace = True)
df_backward_difference_encoder
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lc/q1lfsr356d11n9j92x9l_x080000gn/T/ipykernel_52371/3962613238.py in <module>
#       6
#       7 for col in categorical_cols:
# ----> 8     df_backward_difference_encoder[col + "_encode"]=encoder.fit_transform(df_backward_difference_encoder[col])
#       9
#      10 # df_backward_difference_encoder.drop(columns=categorical_cols, inplace = True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# -> 3729                 raise ValueError("Columns must be same length as key")
#    3730
#    3731             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key
